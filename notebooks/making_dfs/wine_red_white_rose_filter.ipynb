# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/df_nonans.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'type'],
#       dtype='object')

# %%
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
#sparkling = input('Would you like your wine to be sparkling(yes, no, either): ')

# %%
#if sparkling == 'yes':
#    df_filter = df.loc[df['sparkling']=='yes']
#elif sparkling == 'no':
#    df_filter = df.loc[df['sparkling']=='no']
#else:
#    df_filter = df

# %%
wine_type = input('Would you like white, red, rose or any: ')
# Out:
# Would you like white, red, rose or any: rose

# %%
if wine_type == 'red':
    df_filter = df.loc[df['type']=='red']
elif wine_type == 'white': 
    df_filter = df.loc[df['type']=='white']
elif wine_type == 'rose':
    df_filter = df.loc[df['type']=='rose']
else:
    df_filter = df

# %%
white = df.loc[df['type']=='white']

# %%
rose = df.loc[df['type']=='rose']

# %%
white_rose = pd.concat([white, rose], ignore_index=True, sort =False)

# %%
white_rose
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1           US  Tart and snappy, the flavors of lime flesh and...
# 2           US  Pineapple rind, lemon pith and orange blossom ...
# 3       France  This dry and restrained wine offers spice in p...
# 4      Germany  Savory dried thyme notes accent sunnier flavor...
# ...        ...                                                ...
# 36504   France  This is a barely pink rosé, perfect to reflect...
# 36505   France  Soft and ripe, it is gently fruity with light ...
# 36506   France  Close to the beach of Pampelonne, this is a an...
# 36507       US  The use of 100% Syrah gives a deep pink color ...
# 36508       US  Picturesque with a crystalline salmon color, i...
#
#                 designation  points  price           province  \
# 0              Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
white_rose.to_csv('df_w_r.csv')
