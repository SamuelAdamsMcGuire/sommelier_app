# %%
import pickle
import spacy
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB, CategoricalNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
nlp = spacy.load("en_core_web_sm", disable=["parser", "textcat", "ner"])

# %%
df = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %%
counts = df['variety'].value_counts()

# %%
counts[counts > 500]
# Out:
# Pinot Noir                       13272
# Chardonnay                       11753
# Cabernet Sauvignon                9472
# Red Blend                         8946
# Bordeaux-style Red Blend          6915
# Riesling                          5189
# Sauvignon Blanc                   4967
# Syrah                             4142
# Rosé                              3564
# Merlot                            3102
# Nebbiolo                          2804
# Zinfandel                         2714
# Sangiovese                        2707
# Malbec                            2652
# Portuguese Red                    2466
# White Blend                       2360
# Sparkling Blend                   2153
# Tempranillo                       1810
# Rhône-style Red Blend             1471
# Pinot Gris                        1455
# Champagne Blend                   1396
# Cabernet Franc                    1353
# Grüner Veltliner                  1345
# Portuguese White                  1159
# Bordeaux-style White Blend        1066
# Pinot Grigio                      1052
# Gamay                             1025
# Gewürztraminer                    1012
# Viognier                           996
# Shiraz                             836
# Petite Sirah                       770
# Sangiovese Grosso                  751
# Barbera                            721
# Glera                              709
# Port                               668
# Grenache                           651
# Corvina, Rondinella, Molinara      619
# Chenin Blanc                       591
# Tempranillo Blend                  588
# Carmenère                          575
# Name: variety, dtype: int64

# %%
df_trim = df[df['variety'].isin(counts[counts > 500].index)]

# %%
df_trim
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [111797 rows x 13 columns]

# %%
df_trim['type'] = 'red'
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_trim.loc[df.variety == 'White Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Chardonnay', 'type'] = "white"
df_trim.loc[df.variety == 'Riesling', 'type'] = "white"
df_trim.loc[df.variety == 'Sauvignon Blanc', 'type'] = "white"
df_trim.loc[df.variety == 'Sparkling Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Pinot Gris', 'type'] = "white"
df_trim.loc[df.variety == 'Champagne Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Grüner Veltliner ', 'type'] = "white"
df_trim.loc[df.variety == 'Portuguese White', 'type'] = "white"
df_trim.loc[df.variety == 'Bordeaux-style White Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Pinot Grigio', 'type'] = "white"
df_trim.loc[df.variety == 'Gewürztraminer', 'type'] = "white"
df_trim.loc[df.variety == 'Viognier', 'type'] = "white"
df_trim.loc[df.variety == 'Glera', 'type'] = "white"
df_trim.loc[df.variety == 'Chenin Blanc', 'type'] = "white"
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_trim.loc[df.variety == 'Rosé', 'type'] = "rose"

# %%
df_trim['sparkling'] = 'no'
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_trim.loc[df.variety == 'Sparkling Blend', 'sparkling'] = "yes"
df_trim.loc[df.variety == 'Champagne Blend', 'sparkling'] = "yes"

# %%
sparkling = input('Would you like you wine to be sparkling: ')
# Out:
# Would you like you wine to be sparkling: yes

# %%
if sparkling == 'yes':
    df_filter = df_trim.loc[df_trim['sparkling']=='yes']
else:
     df_filter = df_trim.loc[df_trim['sparkling']=='no']

# %%
wine_type = input('Would you like white, red, rose or any: ')
# Out:
# Would you like white, red, rose or any: white

# %%
if wine_type == 'red':
    df_filter = df_filter.loc[df_trim['type']=='red']
elif wine_type == 'white': 
    df_filter = df_filter.loc[df_trim['type']=='white']
else:
    df_filter = df_filter.loc[df_trim['type']=='rose']

# %%
df_filter
# Out:
#        country                                        description  \
# 63      France  This fat, yeasty Champagne is comprised predom...
# 69      France  This cooperative, based in Aÿ, has benefited f...
# 334     France  A ripe, fruity wine that takes its raspberry f...
# 339      Spain  Red in color, with berry and apple aromas, thi...
# 342      Spain  Funky, yeasty aromas of cinnamon, spent lees a...
# ...        ...                                                ...
# 129695      US  Honey-sweet flavors of raspberries, pink grape...
# 129706      US  Mostly Pinot Noir, with a few drops of Chardon...
# 129719  France  In order to maintain freshness and crispness i...
# 129743  France  Crisp and fruity, this mature-tasting wine has...
# 129869      US  This wine hits the mark, combining intriguing ...
#
#                          designation  points  price    province  \
# 63                         Brut Rosé      86   58.0   Champagne
# 69                         Brut Rosé      86   55.0   Champagne
# 334               Mosaïque Rosé Brut      86   42.0   Champagne
# 339                      1887 Rosado      82   13.0   Catalonia
# 342                              NaN      82   11.0   Catalonia
# ...                              ...     ...    ...         ...
# 129695                          Rosé      87   22.0  California
# 129706          VA de VI Ultra Cuvée      87   24.0  California
# 129719  Domaine Vieilles Vignes Brut      90   49.0   Champagne
# 129743                  Réserve Brut      90   70.0   Champagne
# 129869                          Brut      90   25.0  California
#
#              region_1          region_2        taster_name  \
# 63          Champagne               NaN         Roger Voss
# 69          Champagne               NaN         Roger Voss
# 334         Champagne               NaN         Roger Voss
# 339              Cava               NaN  Michael Schachner
# 342              Cava               NaN  Michael Schachner
# ...               ...               ...                ...
# 129695     California  California Other                NaN
# 129706  Sonoma County            Sonoma                NaN
# 129719      Champagne               NaN         Roger Voss
# 129743      Champagne               NaN         Roger Voss
# 129869     California  California Other         Jim Gordon
#
#        taster_twitter_handle  \
# 63                @vossroger
# 69                @vossroger
# 334               @vossroger
# 339              @wineschach
# 342              @wineschach
# ...                      ...
# 129695                   NaN
# 129706                   NaN
# 129719            @vossroger
# 129743            @vossroger
# 129869      @gordone_cellars
#
#                                                     title          variety  \
# 63              Roland Champion NV Brut Rosé  (Champagne)  Champagne Blend
# 69                       Collet NV Brut Rosé  (Champagne)  Champagne Blend
# 334           Jacquart NV Mosaïque Rosé Brut  (Champagne)  Champagne Blend
# 339            Cavas Hill NV 1887 Rosado Sparkling (Cava)  Sparkling Blend
# 342                          Bellisco NV Sparkling (Cava)  Sparkling Blend
# ...                                                   ...              ...
# 129695             Chandon NV Rosé Sparkling (California)  Sparkling Blend
# 129706  Gloria Ferrer NV VA de VI Ultra Cuvée Sparklin...  Sparkling Blend
# 129719  Bruno Gobillard NV Domaine Vieilles Vignes Bru...  Champagne Blend
# 129743             Castelnau NV Réserve Brut  (Champagne)  Champagne Blend
# 129869     Biltmore Estate NV Brut Sparkling (California)  Sparkling Blend
#
#                  winery   type sparkling
# 63      Roland Champion  white       yes
# 69               Collet  white       yes
# 334            Jacquart  white       yes
# 339          Cavas Hill  white       yes
# 342            Bellisco  white       yes
# ...                 ...    ...       ...
# 129695          Chandon  white       yes
# 129706    Gloria Ferrer  white       yes
# 129719  Bruno Gobillard  white       yes
# 129743        Castelnau  white       yes
# 129869  Biltmore Estate  white       yes
#
# [3549 rows x 15 columns]
