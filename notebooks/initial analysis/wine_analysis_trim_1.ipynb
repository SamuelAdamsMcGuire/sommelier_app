# %%
import pickle
import spacy
import pandas as pd
import numpy as np
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB, CategoricalNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
from sklearn import metrics

# %%
nlp = spacy.load("en_core_web_sm", disable=["parser", "textcat", "ner"])

# %%
df = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [129971 rows x 13 columns]

# %%
df.shape
# Out:
# (129971, 13)

# %%
df['variety'].value_counts().head(40)
# Out:
# Pinot Noir                       13272
# Chardonnay                       11753
# Cabernet Sauvignon                9472
# Red Blend                         8946
# Bordeaux-style Red Blend          6915
# Riesling                          5189
# Sauvignon Blanc                   4967
# Syrah                             4142
# Rosé                              3564
# Merlot                            3102
# Nebbiolo                          2804
# Zinfandel                         2714
# Sangiovese                        2707
# Malbec                            2652
# Portuguese Red                    2466
# White Blend                       2360
# Sparkling Blend                   2153
# Tempranillo                       1810
# Rhône-style Red Blend             1471
# Pinot Gris                        1455
# Champagne Blend                   1396
# Cabernet Franc                    1353
# Grüner Veltliner                  1345
# Portuguese White                  1159
# Bordeaux-style White Blend        1066
# Pinot Grigio                      1052
# Gamay                             1025
# Gewürztraminer                    1012
# Viognier                           996
# Shiraz                             836
# Petite Sirah                       770
# Sangiovese Grosso                  751
# Barbera                            721
# Glera                              709
# Port                               668
# Grenache                           651
# Corvina, Rondinella, Molinara      619
# Chenin Blanc                       591
# Tempranillo Blend                  588
# Carmenère                          575
# Name: variety, dtype: int64

# %%
df['single_variety'] = df['variety'].value_counts()==1

# %%
df.variety.value_counts().loc[lambda x: x>500]
# Out:
# Pinot Noir                       13272
# Chardonnay                       11753
# Cabernet Sauvignon                9472
# Red Blend                         8946
# Bordeaux-style Red Blend          6915
# Riesling                          5189
# Sauvignon Blanc                   4967
# Syrah                             4142
# Rosé                              3564
# Merlot                            3102
# Nebbiolo                          2804
# Zinfandel                         2714
# Sangiovese                        2707
# Malbec                            2652
# Portuguese Red                    2466
# White Blend                       2360
# Sparkling Blend                   2153
# Tempranillo                       1810
# Rhône-style Red Blend             1471
# Pinot Gris                        1455
# Champagne Blend                   1396
# Cabernet Franc                    1353
# Grüner Veltliner                  1345
# Portuguese White                  1159
# Bordeaux-style White Blend        1066
# Pinot Grigio                      1052
# Gamay                             1025
# Gewürztraminer                    1012
# Viognier                           996
# Shiraz                             836
# Petite Sirah                       770
# Sangiovese Grosso                  751
# Barbera                            721
# Glera                              709
# Port                               668
# Grenache                           651
# Corvina, Rondinella, Molinara      619
# Chenin Blanc                       591
# Tempranillo Blend                  588
# Carmenère                          575
# Name: variety, dtype: int64

# %%
counts = df['variety'].value_counts()

# %%
counts[counts > 500]
# Out:
# Pinot Noir                       13272
# Chardonnay                       11753
# Cabernet Sauvignon                9472
# Red Blend                         8946
# Bordeaux-style Red Blend          6915
# Riesling                          5189
# Sauvignon Blanc                   4967
# Syrah                             4142
# Rosé                              3564
# Merlot                            3102
# Nebbiolo                          2804
# Zinfandel                         2714
# Sangiovese                        2707
# Malbec                            2652
# Portuguese Red                    2466
# White Blend                       2360
# Sparkling Blend                   2153
# Tempranillo                       1810
# Rhône-style Red Blend             1471
# Pinot Gris                        1455
# Champagne Blend                   1396
# Cabernet Franc                    1353
# Grüner Veltliner                  1345
# Portuguese White                  1159
# Bordeaux-style White Blend        1066
# Pinot Grigio                      1052
# Gamay                             1025
# Gewürztraminer                    1012
# Viognier                           996
# Shiraz                             836
# Petite Sirah                       770
# Sangiovese Grosso                  751
# Barbera                            721
# Glera                              709
# Port                               668
# Grenache                           651
# Corvina, Rondinella, Molinara      619
# Chenin Blanc                       591
# Tempranillo Blend                  588
# Carmenère                          575
# Name: variety, dtype: int64

# %%
df_trim = df[df['variety'].isin(counts[counts > 500].index)]

# %%
df_trim
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery single_variety
# 0                                        Nicosia            NaN
# 1                            Quinta dos Avidagos            NaN
# 2                                      Rainstorm            NaN
# 3                                     St. Julian            NaN
# 4                                   Sweet Cheeks            NaN
# ...                                          ...            ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)            NaN
# 129967                                  Citation            NaN
# 129968                           Domaine Gresser            NaN
# 129969                      Domaine Marcel Deiss            NaN
# 129970                          Domaine Schoffit            NaN
#
# [111797 rows x 14 columns]

# %%
df_trim['type'] = 'red'
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_trim.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery single_variety type
# 0     White Blend              Nicosia            NaN  red
# 1  Portuguese Red  Quinta dos Avidagos            NaN  red
# 2      Pinot Gris            Rainstorm            NaN  red
# 3        Riesling           St. Julian            NaN  red
# 4      Pinot Noir         Sweet Cheeks            NaN  red

# %%
df_trim.loc[df.variety == 'White Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Chardonnay', 'type'] = "white"
df_trim.loc[df.variety == 'Riesling', 'type'] = "white"
df_trim.loc[df.variety == 'Sauvignon Blanc', 'type'] = "white"
df_trim.loc[df.variety == 'Sparkling Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Pinot Gris', 'type'] = "white"
df_trim.loc[df.variety == 'Champagne Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Grüner Veltliner ', 'type'] = "white"
df_trim.loc[df.variety == 'Portuguese White', 'type'] = "white"
df_trim.loc[df.variety == 'Bordeaux-style White Blend', 'type'] = "white"
df_trim.loc[df.variety == 'Pinot Grigio', 'type'] = "white"
df_trim.loc[df.variety == 'Gewürztraminer', 'type'] = "white"
df_trim.loc[df.variety == 'Viognier', 'type'] = "white"
df_trim.loc[df.variety == 'Glera', 'type'] = "white"
df_trim.loc[df.variety == 'Chenin Blanc', 'type'] = "white"
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
df_trim.loc[df.variety == 'Rosé', 'type'] = "rose"

# %%
df_trim.loc[df.variety == 'Chenin Blanc']
# Out:
#              country                                        description  \
# 29                US  Clarksburg is becoming a haven for Chenin Blan...
# 137     South Africa  This is great Chenin Blanc, wood fermented but...
# 197     South Africa  This is a concentrated, fairly full and lush C...
# 226     South Africa  This is a round and rich wine, with notes of w...
# 483     South Africa  A glimmer of toast and honey add depth to the ...
# ...              ...                                                ...
# 128992  South Africa  This luminous and unique Chenin Blanc straw wi...
# 129089            US  The abundant minerality of this Mendocino Chen...
# 129207  South Africa  There's a subtle honeyed edge to this otherwis...
# 129828  South Africa  This wine has a slightly quiet and tight nose,...
# 129945            US  Hailing from one of the more popular vineyards...
#
#                              designation  points  price        province  \
# 29                                   NaN      86   16.0      California
# 137                      Hope Marguerite      90    NaN      Walker Bay
# 197                            21 Gables      90   23.0    Western Cape
# 226                                  NaN      90   20.0    Stellenbosch
# 483                                  NaN      87   12.0    Stellenbosch
# ...                                  ...     ...    ...             ...
# 128992                        Straw Wine      93   50.0    Stellenbosch
# 129089                               NaN      87   15.0      California
# 129207                               NaN      86   10.0  Coastal Region
# 129828                               NaN      86    9.0       Robertson
# 129945  Jurassic Park Vineyard Old Vines      90   20.0      California
#
#                  region_1        region_2      taster_name  \
# 29             Clarksburg  Central Valley   Virginie Boone
# 137                   NaN             NaN       Roger Voss
# 197                   NaN             NaN    Lauren Buzzeo
# 226                   NaN             NaN    Lauren Buzzeo
# 483                   NaN             NaN    Lauren Buzzeo
# ...                   ...             ...              ...
# 128992                NaN             NaN    Lauren Buzzeo
# 129089   Mendocino County             NaN   Virginie Boone
# 129207                NaN             NaN    Lauren Buzzeo
# 129828                NaN             NaN  Susan Kostrzewa
# 129945  Santa Ynez Valley   Central Coast    Matt Kettmann
#
#        taster_twitter_handle  \
# 29                   @vboone
# 137               @vossroger
# 197                @laurbuzz
# 226                @laurbuzz
# 483                @laurbuzz
# ...                      ...
# 128992             @laurbuzz
# 129089               @vboone
# 129207             @laurbuzz
# 129828         @suskostrzewa
# 129945         @mattkettmann
#
#                                                     title       variety  \
# 29      Clarksburg Wine Company 2010 Chenin Blanc (Cla...  Chenin Blanc
# 137     Beaumont 2005 Hope Marguerite Chenin Blanc (Wa...  Chenin Blanc
# 197      Spier 2014 21 Gables Chenin Blanc (Western Cape)  Chenin Blanc
# 226            Oldenburg 2014 Chenin Blanc (Stellenbosch)  Chenin Blanc
# 483            Cape View 2011 Chenin Blanc (Stellenbosch)  Chenin Blanc
# ...                                                   ...           ...
# 128992  de Trafford 2008 Straw Wine Chenin Blanc (Stel...  Chenin Blanc
# 129089      Graziano 2011 Chenin Blanc (Mendocino County)  Chenin Blanc
# 129207    MAN Vintners 2010 Chenin Blanc (Coastal Region)  Chenin Blanc
# 129828     Robertson Winery 2008 Chenin Blanc (Robertson)  Chenin Blanc
# 129945  Birichino 2013 Jurassic Park Vineyard Old Vine...  Chenin Blanc
#
#                          winery single_variety   type
# 29      Clarksburg Wine Company            NaN  white
# 137                    Beaumont            NaN  white
# 197                       Spier            NaN  white
# 226                   Oldenburg            NaN  white
# 483                   Cape View            NaN  white
# ...                         ...            ...    ...
# 128992              de Trafford            NaN  white
# 129089                 Graziano            NaN  white
# 129207             MAN Vintners            NaN  white
# 129828         Robertson Winery            NaN  white
# 129945                Birichino            NaN  white
#
# [591 rows x 15 columns]

# %%
df_trim
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# 1                                     Avidagos      87   15.0
# 2                                          NaN      87   14.0
# 3                         Reserve Late Harvest      87   13.0
# 4           Vintner's Reserve Wild Child Block      87   65.0
# ...                                        ...     ...    ...
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0
# 129967                                     NaN      90   75.0
# 129968                                   Kritt      90   30.0
# 129969                                     NaN      90   32.0
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                  province             region_1           region_2  \
# 0       Sicily & Sardinia                 Etna                NaN
# 1                   Douro                  NaN                NaN
# 2                  Oregon    Willamette Valley  Willamette Valley
# 3                Michigan  Lake Michigan Shore                NaN
# 4                  Oregon    Willamette Valley  Willamette Valley
# ...                   ...                  ...                ...
# 129966              Mosel                  NaN                NaN
# 129967             Oregon               Oregon       Oregon Other
# 129968             Alsace               Alsace                NaN
# 129969             Alsace               Alsace                NaN
# 129970             Alsace               Alsace                NaN
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 129966  Anna Lee C. Iijima                   NaN
# 129967        Paul Gregutt           @paulgwine
# 129968          Roger Voss            @vossroger
# 129969          Roger Voss            @vossroger
# 129970          Roger Voss            @vossroger
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery single_variety   type
# 0                                        Nicosia            NaN  white
# 1                            Quinta dos Avidagos            NaN    red
# 2                                      Rainstorm            NaN  white
# 3                                     St. Julian            NaN  white
# 4                                   Sweet Cheeks            NaN    red
# ...                                          ...            ...    ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)            NaN  white
# 129967                                  Citation            NaN    red
# 129968                           Domaine Gresser            NaN  white
# 129969                      Domaine Marcel Deiss            NaN  white
# 129970                          Domaine Schoffit            NaN  white
#
# [111797 rows x 15 columns]

# %%
corpus = df_trim['description']

# %%
corpus
# Out:
# 0         Aromas include tropical fruit, broom, brimston...
# 1         This is ripe and fruity, a wine that is smooth...
# 2         Tart and snappy, the flavors of lime flesh and...
# 3         Pineapple rind, lemon pith and orange blossom ...
# 4         Much like the regular bottling from 2012, this...
#                                 ...
# 129966    Notes of honeysuckle and cantaloupe sweeten th...
# 129967    Citation is given as much as a decade of bottl...
# 129968    Well-drained gravel soil gives this wine its c...
# 129969    A dry style of Pinot Gris, this is crisp with ...
# 129970    Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 111797, dtype: object

# %%
y = df_trim['variety']

# %%
y.value_counts()
# Out:
# Pinot Noir                       13272
# Chardonnay                       11753
# Cabernet Sauvignon                9472
# Red Blend                         8946
# Bordeaux-style Red Blend          6915
# Riesling                          5189
# Sauvignon Blanc                   4967
# Syrah                             4142
# Rosé                              3564
# Merlot                            3102
# Nebbiolo                          2804
# Zinfandel                         2714
# Sangiovese                        2707
# Malbec                            2652
# Portuguese Red                    2466
# White Blend                       2360
# Sparkling Blend                   2153
# Tempranillo                       1810
# Rhône-style Red Blend             1471
# Pinot Gris                        1455
# Champagne Blend                   1396
# Cabernet Franc                    1353
# Grüner Veltliner                  1345
# Portuguese White                  1159
# Bordeaux-style White Blend        1066
# Pinot Grigio                      1052
# Gamay                             1025
# Gewürztraminer                    1012
# Viognier                           996
# Shiraz                             836
# Petite Sirah                       770
# Sangiovese Grosso                  751
# Barbera                            721
# Glera                              709
# Port                               668
# Grenache                           651
# Corvina, Rondinella, Molinara      619
# Chenin Blanc                       591
# Tempranillo Blend                  588
# Carmenère                          575
# Name: variety, dtype: int64

# %%
def custom_tokenizer(text):
    '''
    used to filter out unwanted words, punctuation, and so on
    '''
    tokens = []
    for t in nlp(text):
        if not(len(t) < 2 or t.is_stop or t.like_num or 
               t.is_punct or not t.is_alpha):
            tokens.append(t.lemma_)
    return tokens

# %%
bow = CountVectorizer(tokenizer=custom_tokenizer, 
                      ngram_range=(1, 1), 
                      min_df=0.01, 
                      max_df=0.99)

# %%
corpus_train, corpus_test, y_train, y_test = train_test_split(corpus, y, 
                                                              test_size=0.4, 
                                                              train_size=0.6)

# %%
X_train = bow.fit_transform(corpus_train)

# %%
X_train.shape
# Out:
# (67078, 397)

# %%
X_test = bow.transform(corpus_test)

# %%
m_nb = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('NB', BernoulliNB())
])

# %%
cross_val_score(m_nb, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
# Out:
# 0.5015058364539758

# %%
m_nb.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('TfIdf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('NB',
#                  BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None,
#                              fit_prior=True))],
#          verbose=False)

# %%
m_nb.predict(X_test)
# Out:
# array(['Pinot Noir', 'Cabernet Sauvignon', 'Bordeaux-style Red Blend',
#        ..., 'Red Blend', 'Portuguese White', 'Chardonnay'], dtype='<U35')

# %%
#metrics.accuracy_score(y_test, m_nb.predict(X_test))

# %%
# get the NaiveBayes form the pipeline and return marginal probabilites P(X|Y=k)
feat_imp = m_nb['NB'].feature_log_prob_
feat_imp.shape
# Out:
# (637, 393)

# %%
feat_imp = pd.DataFrame(feat_imp, columns=bow.get_feature_names()).T
np.exp(feat_imp)
# Out:
#           0         1         2         3    4       5         6         7    \
# accent   0.25  0.024390  0.039024  0.333333  0.2  0.0625  0.333333  0.017857
# acid     0.25  0.097561  0.004878  0.333333  0.2  0.0625  0.333333  0.053571
# acidic   0.25  0.024390  0.004878  0.333333  0.2  0.0625  0.333333  0.028571
# acidity  0.50  0.121951  0.107317  0.333333  0.2  0.7500  0.333333  0.253571
# add      0.25  0.048780  0.039024  0.333333  0.2  0.0625  0.333333  0.007143
# ...       ...       ...       ...       ...  ...     ...       ...       ...
# yellow   0.25  0.024390  0.004878  0.333333  0.2  0.6250  0.666667  0.035714
# young    0.25  0.024390  0.034146  0.333333  0.2  0.0625  0.333333  0.010714
# z        0.25  0.024390  0.019512  0.333333  0.2  0.1250  0.333333  0.010714
# zest     0.25  0.024390  0.009756  0.333333  0.2  0.5000  0.333333  0.007143
# zesty    0.25  0.024390  0.019512  0.333333  0.2  0.0625  0.333333  0.057143
#
#           8     9    ...   627       628       629       630  631       632  \
# accent   0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.2  0.034056
# acid     0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.2  0.020433
# acidic   0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.4  0.006811
# acidity  0.25  0.25  ...  0.25  0.333333  0.363636  0.500000  0.2  0.115789
# add      0.25  0.25  ...  0.25  0.333333  0.090909  0.071429  0.4  0.028483
# ...       ...   ...  ...   ...       ...       ...       ...  ...       ...
# yellow   0.25  0.25  ...  0.25  0.333333  0.318182  0.285714  0.2  0.000619
# young    0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.2  0.014241
# z        0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.2  0.005573
# zest     0.25  0.25  ...  0.25  0.333333  0.409091  0.071429  0.2  0.001858
# zesty    0.25  0.25  ...  0.25  0.333333  0.045455  0.071429  0.2  0.002477
#
#               633       634       635       636
# accent   0.333333  0.014493  0.333333  0.333333
# acid     0.333333  0.014493  0.333333  0.333333
# acidic   0.666667  0.021739  0.333333  0.333333
# acidity  0.333333  0.275362  0.333333  0.333333
# add      0.333333  0.050725  0.333333  0.333333
# ...           ...       ...       ...       ...
# yellow   0.666667  0.007246  0.333333  0.333333
# young    0.333333  0.065217  0.333333  0.333333
# z        0.333333  0.007246  0.333333  0.333333
# zest     0.333333  0.007246  0.333333  0.333333
# zesty    0.333333  0.014493  0.333333  0.333333
#
# [393 rows x 637 columns]

# %%
feat_imp.sum(axis=1).sort_values() #find most common words
# Out:
# riesling     -1546.004733
# sangiovese   -1543.282498
# verdot       -1528.567210
# cab          -1527.819434
# malbec       -1515.469469
#                  ...
# aroma         -695.482612
# finish        -677.110674
# fruit         -587.061196
# flavor        -517.176112
# wine          -478.741285
# Length: 393, dtype: float64

# %%
np.exp(feat_imp[1].sort_values(ascending=False))
# Out:
# wine      0.682927
# red       0.658537
# flavor    0.609756
# cherry    0.609756
# nose      0.560976
#             ...
# nicely    0.024390
# noir      0.024390
# nuance    0.024390
# oak       0.024390
# accent    0.024390
# Name: 1, Length: 393, dtype: float64

# %%
m_nb.predict_proba(bow.transform(['cherry flavor nice oak accent'])).max()
# Out:
# 0.3052741119504553

# %%
m_nbg = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('NB', GaussianNB())
])

# %%
cross_val_score(m_nbg, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   % (min_groups, self.n_splits)), UserWarning)
# nan

# %%
m_nbm = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('NB', MultinomialNB())
])

# %%
cross_val_score(m_nbm, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   % (min_groups, self.n_splits)), UserWarning)
# 0.4104793436297703

# %%
m_nbc = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('NB', CategoricalNB())
])

# %%
cross_val_score(m_nbc, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   % (min_groups, self.n_splits)), UserWarning)
# nan

# %%
m_rf = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('RFC', RandomForestClassifier())
])

# %%
cross_val_score(m_rf, X_train, y_train, scoring='accuracy',  cv=4).mean()
# Out:
# /home/samuelmcguire/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=4.
#   % (min_groups, self.n_splits)), UserWarning)

# %%
m_rfr = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('RFC', RandomForestRegressor())
])

# %%
cross_val_score(m_rfr, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
# Out:
# nan

# %%
m = Pipeline([
    ('TfIdf', TfidfTransformer()),
    ('LogReg', LogisticRegression(class_weight='balanced'))
    ])

# %%
cross_val_score(m, X_train, y_train, scoring='accuracy', n_jobs=4, cv=4).mean()
